# %% [markdown]
# # Dogs cats classification

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator as IDG
from tensorflow.keras.applications.vgg16 import preprocess_input
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPool2D, Flatten
from sklearn.utils import shuffle
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
import os
import random
import glob
import shutil

# %% [markdown]
# # Train test splitting

# %%
all_cats_path = "../../Documents/Datasets/PetImages/cat/"
all_dogs_path = "../../Documents/Datasets/PetImages/dog/"

# number of cat images.
num_cats = len(os.listdir(all_cats_path))

# number of dogs images
num_dogs = len(os.listdir(all_dogs_path))

if os.path.isdir("../../Documents/Datasets/PetImages/train/cat") is False:
    os.mkdir("../../Documents/Datasets/PetImages/train/cat", )
    os.mkdir("../../Documents/Datasets/PetImages/train/dog")
    os.mkdir("../../Documents/Datasets/PetImages/test/cat")
    os.mkdir("../../Documents/Datasets/PetImages/test/dog")

    for image in random.sample(glob.glob(all_cats_path+"*"), int(0.7 * (num_cats))):
        shutil.copy2(image, '../../Documents/Datasets/PetImages/train/cat')

    for image in random.sample(glob.glob(all_dogs_path+"*"), int(0.7 * (num_dogs))):
        shutil.copy2(image, '../../Documents/Datasets/PetImages/train/dog')

    for image in random.sample(glob.glob(all_cats_path+"*"), int(0.3 * (num_cats))):
        shutil.copy2(image, '../../Documents/Datasets/PetImages/test/cat')

    for image in random.sample(glob.glob(all_dogs_path+"*"), int(0.3 * (num_dogs))):
        shutil.copy2(image, '../../Documents/Datasets/PetImages/test/dog')

# %% [markdown]
# # Split the dataset to testing and training sets.

# %%
# Loading the dogs and cats data and preprocessing it.

# images paths.
train_data_path = "../../Documents/Datasets/PetImages/train/"
test_data_path = "../../Documents/Datasets/PetImages/test/"


# Preprocess the data.
train_data = IDG(preprocessing_function=preprocess_input).flow_from_directory(directory=train_data_path, classes=["cat", "dog"], batch_size=50, target_size=(300, 300))

test_data = IDG(preprocessing_function=preprocess_input).flow_from_directory(directory=test_data_path, classes=["cat", "dog"], batch_size=50, target_size=(300, 300))
# Out:
# Found 8258 images belonging to 2 classes.
# Found 3298 images belonging to 2 classes.

# %%
model = Sequential([
    Input(shape=(300, 300, 3)),
    Conv2D(filters=32, kernel_size=(3, 3), activation="relu", padding='same'),
    MaxPool2D(pool_size=(2, 2), strides=2),
    Conv2D(filters=64, kernel_size=(3, 3), activation="relu", padding='same'),
    MaxPool2D(pool_size=(2, 2), strides=2),
    Conv2D(filters=128, kernel_size=(3, 3), activation="relu", padding='same'),
    MaxPool2D(pool_size=(2, 2), strides=2),
    Conv2D(filters=324, kernel_size=(3, 3), activation="relu", padding='same'),
    MaxPool2D(pool_size=(2, 2), strides=2),
    Flatten(),
    Dense(activation="softmax", units=2)
])

model.compile(optimizer=Adam(learning_rate=0.00001), loss="categorical_crossentropy", metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_18 (Conv2D)              │ (None, 300, 300, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_18 (MaxPooling2D) │ (None, 150, 150, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_19 (Conv2D)              │ (None, 150, 150, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_19 (MaxPooling2D) │ (None, 75, 75, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_20 (Conv2D)              │ (None, 75, 75, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_20 (MaxPooling2D) │ (None, 37, 37, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_21 (Conv2D)              │ (None, 37, 37, 324)    │       373,572 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_21 (MaxPooling2D) │ (None, 18, 18, 324)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_5 (Flatten)             │ (None, 104976)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 2)              │       209,954 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 676,774 (2.58 MB)
#  Trainable params: 676,774 (2.58 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # fit the model

# %%
model.fit(x=train_data, verbose=True, epochs=20, batch_size=20, shuffle=True)
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 13
# Epoch 1/20
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1090s 7s/step - accuracy: 0.9689 - loss: 0.1032
# Epoch 2/20
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1097s 7s/step - accuracy: 0.9730 - loss: 0.0850
# Epoch 3/20
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1089s 7s/step - accuracy: 0.9737 - loss: 0.0824
# Epoch 4/20
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1098s 7s/step - accuracy: 0.9809 - loss: 0.0597
# Epoch 5/20
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1080s 7s/step - accuracy: 0.9869 - loss: 0.0461
# Epoch 6/20
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1084s 7s/step - accuracy: 0.9885 - loss: 0.0400
# Epoch 7/20
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1084s 7s/step - accuracy: 0.9908 - loss: 0.0329
# Epoch 8/20
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1082s 7s/step - accuracy: 0.9920 - loss: 0.0283
# Epoch 9/20
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1080s 7s/step - accuracy: 0.9939 - loss: 0.0239
# Epoch 10/20
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1081s 7s/step - accuracy: 0.9958 - loss: 0.0205
# Epoch 11/20
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1082s 7s/step - accuracy: 0.9978 - loss: 0.0146
# Epoch 12/20
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1097s 6s/step - accuracy: 0.9994 - loss: 0.0114
# Epoch 13/20
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1082s 7s/step - accuracy: 0.9994 - loss: 0.0092
# Epoch 14/20
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1081s 7s/step - accuracy: 0.9994 - loss: 0.0092
# Epoch 15/20
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1078s 6s/step - accuracy: 0.9999 - loss: 0.0075
# Epoch 16/20
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1078s 6s/step - accuracy: 1.0000 - loss: 0.0067
# Epoch 17/20
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1079s 6s/step - accuracy: 0.9998 - loss: 0.0053
# Epoch 18/20
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1076s 6s/step - accuracy: 0.9999 - loss: 0.0047
# Epoch 19/20
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1081s 7s/step - accuracy: 1.0000 - loss: 0.0038
# Epoch 20/20
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1076s 6s/step - accuracy: 1.0000 - loss: 0.0034

# %%
model.predict(test_data)
# Out:
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step
# array([[9.9999994e-01, 3.5702040e-08],
#        [9.9999875e-01, 1.2299618e-06],
#        [9.8123491e-01, 1.8765006e-02],
#        ...,
#        [9.9998111e-01, 1.8862913e-05],
#        [9.9990660e-01, 9.3326060e-05],
#        [9.9999970e-01, 2.4955062e-07]], shape=(3298, 2), dtype=float32)

# %%
model.save('../../Documents/Datasets/PetImages/cat_dog_model.keras')
