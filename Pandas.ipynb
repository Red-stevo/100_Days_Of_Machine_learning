# %%
import pandas as pd

df = pd.DataFrame({"names":["stephen", "muiru"], "object":["human", "male"]})

print(df);
# Out:
#      names object
# 0  stephen  human
# 1    muiru   male

# %%
df.index = ["row 1", "row 2"]

print(df)
# Out:
#          names object
# row 1  stephen  human
# row 2    muiru   male

# %%
survey = pd.read_csv("./files/annual-enterprise-survey-2023-financial-year-provisional.csv", index_col="Variable_code")

survey.head()
# Out:
#                Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# Variable_code
# H01            2023                     Level 1                99999
# H04            2023                     Level 1                99999
# H05            2023                     Level 1                99999
# H07            2023                     Level 1                99999
# H08            2023                     Level 1                99999
#
#               Industry_name_NZSIOC               Units  \
# Variable_code
# H01                 All industries  Dollars (millions)
# H04                 All industries  Dollars (millions)
# H05                 All industries  Dollars (millions)
# H07                 All industries  Dollars (millions)
# H08                 All industries  Dollars (millions)
#
#                                                  Variable_name  \
# Variable_code
# H01                                               Total income
# ...

# %%
survey.iloc[0]
# Out:
# Year                                                                        2023
# Industry_aggregation_NZSIOC                                              Level 1
# Industry_code_NZSIOC                                                       99999
# Industry_name_NZSIOC                                              All industries
# Units                                                         Dollars (millions)
# Variable_name                                                       Total income
# Variable_category                                          Financial performance
# Value                                                                     930995
# Industry_code_ANZSIC06         ANZSIC06 divisions A-S (excluding classes K633...
# Name: H01, dtype: object

# %%
survey.iloc[2:,0]
# Out:
# Variable_code
# H05    2023
# H07    2023
# H08    2023
# H09    2023
# H10    2023
#        ...
# H37    2013
# H38    2013
# H39    2013
# H40    2013
# H41    2013
# Name: Year, Length: 50983, dtype: int64

# %%
survey.iloc[2:4]
# Out:
#                Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# Variable_code
# H05            2023                     Level 1                99999
# H07            2023                     Level 1                99999
#
#               Industry_name_NZSIOC               Units  \
# Variable_code
# H05                 All industries  Dollars (millions)
# H07                 All industries  Dollars (millions)
#
#                                    Variable_name      Variable_category  \
# Variable_code
# H05            Interest, dividends and donations  Financial performance
# H07                         Non-operating income  Financial performance
#
#                Value                             Industry_code_ANZSIC06
# Variable_code
# H05            84354  ANZSIC06 divisions A-S (excluding classes K633...
# H07            25010  ANZSIC06 divisions A-S (excluding classes K633...

# %%
survey.iloc[2:6,[1,2,3,4]]
# Out:
#               Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# Variable_code
# H05                               Level 1                99999
# H07                               Level 1                99999
# H08                               Level 1                99999
# H09                               Level 1                99999
#
#               Industry_name_NZSIOC               Units
# Variable_code
# H05                 All industries  Dollars (millions)
# H07                 All industries  Dollars (millions)
# H08                 All industries  Dollars (millions)
# H09                 All industries  Dollars (millions)

# %%
survey.iloc[[2,3,4,-2],[0,1,2,4,5,-1, -2]]
# Out:
#                Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# Variable_code
# H05            2023                     Level 1                99999
# H07            2023                     Level 1                99999
# H08            2023                     Level 1                99999
# H40            2013                     Level 3                 ZZ11
#
#                             Units                      Variable_name  \
# Variable_code
# H05            Dollars (millions)  Interest, dividends and donations
# H07            Dollars (millions)               Non-operating income
# H08            Dollars (millions)                  Total expenditure
# H40                    Percentage             Return on total assets
#
#                                           Industry_code_ANZSIC06   Value
# Variable_code
# H05            ANZSIC06 divisions A-S (excluding classes K633...   84354
# H07            ANZSIC06 divisions A-S (excluding classes K633...   25010
# ...

# %%
survey.iloc[40:]
# Out:
#                Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# Variable_code
# H12            2023                     Level 1                   AA
# H13            2023                     Level 1                   AA
# H19            2023                     Level 1                   AA
# H20            2023                     Level 1                   AA
# H21            2023                     Level 1                   AA
# ...             ...                         ...                  ...
# H37            2013                     Level 3                 ZZ11
# H38            2013                     Level 3                 ZZ11
# H39            2013                     Level 3                 ZZ11
# H40            2013                     Level 3                 ZZ11
# H41            2013                     Level 3                 ZZ11
#
#                             Industry_name_NZSIOC               Units  \
# Variable_code
# ...

# %%
survey.loc[:]
# Out:
#                Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# Variable_code
# H01            2023                     Level 1                99999
# H04            2023                     Level 1                99999
# H05            2023                     Level 1                99999
# H07            2023                     Level 1                99999
# H08            2023                     Level 1                99999
# ...             ...                         ...                  ...
# H37            2013                     Level 3                 ZZ11
# H38            2013                     Level 3                 ZZ11
# H39            2013                     Level 3                 ZZ11
# H40            2013                     Level 3                 ZZ11
# H41            2013                     Level 3                 ZZ11
#
#                      Industry_name_NZSIOC               Units  \
# Variable_code
# ...

# %%
survey.loc["H40",["Value", "Year", "Industry_code_ANZSIC06"]]
# Out:
#               Value  Year                             Industry_code_ANZSIC06
# Variable_code
# H40               4  2023  ANZSIC06 divisions A-S (excluding classes K633...
# H40               3  2023                                ANZSIC06 division A
# H40               4  2023               ANZSIC06 groups A011, A012, and A013
# H40               4  2023               ANZSIC06 groups A011, A012, and A013
# H40               3  2023                      ANZSIC06 groups A014 and A015
# ...             ...   ...                                                ...
# H40               8  2013  ANZSIC06 division S (excluding classes S9540, ...
# H40              15  2013               ANZSIC06 groups S941, S942, and S949
# H40              15  2013               ANZSIC06 groups S951, S952, and S953
# H40               5  2013                                ANZSIC06 group S955
# H40               5  2013  ANZSIC06 groups C111, C112, C113, C114, C115, ...
#
# [1529 rows x 3 columns]

# %%
survey.loc[(survey.Year >= 2013) & (survey.Industry_aggregation_NZSIOC == "Level 3") & (survey.Variable_category == "Financial ratios")]
# Out:
#                Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# Variable_code
# H34            2023                     Level 3                 AA11
# H35            2023                     Level 3                 AA11
# H36            2023                     Level 3                 AA11
# H37            2023                     Level 3                 AA11
# H39            2023                     Level 3                 AA11
# ...             ...                         ...                  ...
# H37            2013                     Level 3                 ZZ11
# H38            2013                     Level 3                 ZZ11
# H39            2013                     Level 3                 ZZ11
# H40            2013                     Level 3                 ZZ11
# H41            2013                     Level 3                 ZZ11
#
#                          Industry_name_NZSIOC       Units  \
# Variable_code
# ...

# %%
survey.loc[survey.Year.isnull()]
# Out:
# Empty DataFrame
# Columns: [Year, Industry_aggregation_NZSIOC, Industry_code_NZSIOC, Industry_name_NZSIOC, Units, Variable_name, Variable_category, Value, Industry_code_ANZSIC06]
# Index: []

# %%
survey.loc[survey.Year.isin([2014, 2012]) & (survey["Industry_aggregation_NZSIOC"] == "Level 1")]
# Out:
#                Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# Variable_code
# H01            2014                     Level 1                99999
# H04            2014                     Level 1                99999
# H05            2014                     Level 1                99999
# H07            2014                     Level 1                99999
# H08            2014                     Level 1                99999
# ...             ...                         ...                  ...
# H36            2014                     Level 1                   RS
# H37            2014                     Level 1                   RS
# H39            2014                     Level 1                   RS
# H40            2014                     Level 1                   RS
# H41            2014                     Level 1                   RS
#
#                               Industry_name_NZSIOC               Units  \
# Variable_code
# ...

# %%
survey.columns
# Out:
# Index(['Year', 'Industry_aggregation_NZSIOC', 'Industry_code_NZSIOC',
#        'Industry_name_NZSIOC', 'Units', 'Variable_name', 'Variable_category',
#        'Value', 'Industry_code_ANZSIC06'],
#       dtype='object')

# %%
survey.shape
# Out:
# (50985, 9)

# %%
year_mean = survey.Year.mean()

centered_mean = survey.Year.map(lambda year : year - year_mean

# %%
centered_mean.mean() #this means should be zero.
# Out:
# 0.0

# %%
year_mean = survey.Year.mean()

def remean_year_col(row):
    row.Year = row.Year - year_mean
    return row

survey.apply(remean_year_col, axis="columns")
# Out:
#                Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# Variable_code
# H01             5.0                     Level 1                99999
# H04             5.0                     Level 1                99999
# H05             5.0                     Level 1                99999
# H07             5.0                     Level 1                99999
# H08             5.0                     Level 1                99999
# ...             ...                         ...                  ...
# H37            -5.0                     Level 3                 ZZ11
# H38            -5.0                     Level 3                 ZZ11
# H39            -5.0                     Level 3                 ZZ11
# H40            -5.0                     Level 3                 ZZ11
# H41            -5.0                     Level 3                 ZZ11
#
#                      Industry_name_NZSIOC               Units  \
# Variable_code
# ...

# %%
survey.Value.describe()
# Out:
# count     50985
# unique    13673
# top           C
# freq       2285
# Name: Value, dtype: object

# %%
survey.Year.median()
# Out:
# 2018.0

# %%
survey.Year.unique()
# Out:
# array([2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013])

# %%
series = pd.Series(data=None, index=survey.Year.unique())
series
# Out:
# 2023   NaN
# 2022   NaN
# 2021   NaN
# 2020   NaN
# 2019   NaN
# 2018   NaN
# 2017   NaN
# 2016   NaN
# 2015   NaN
# 2014   NaN
# 2013   NaN
# dtype: float64

# %%
survey.Year.value_counts()
# Out:
# Year
# 2023    4635
# 2022    4635
# 2021    4635
# 2020    4635
# 2019    4635
# 2018    4635
# 2017    4635
# 2016    4635
# 2015    4635
# 2014    4635
# 2013    4635
# Name: count, dtype: int64

# %%
survey.groupby("Year").Year.count()
# Out:
# Year
# 2013    4635
# 2014    4635
# 2015    4635
# 2016    4635
# 2017    4635
# 2018    4635
# 2019    4635
# 2020    4635
# 2021    4635
# 2022    4635
# 2023    4635
# Name: Year, dtype: int64

# %%
survey
# Out:
#                Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# Variable_code
# H01            2023                     Level 1                99999
# H04            2023                     Level 1                99999
# H05            2023                     Level 1                99999
# H07            2023                     Level 1                99999
# H08            2023                     Level 1                99999
# ...             ...                         ...                  ...
# H37            2013                     Level 3                 ZZ11
# H38            2013                     Level 3                 ZZ11
# H39            2013                     Level 3                 ZZ11
# H40            2013                     Level 3                 ZZ11
# H41            2013                     Level 3                 ZZ11
#
#                      Industry_name_NZSIOC               Units  \
# Variable_code
# ...

# %%
survey.groupby(["Year", "Variable_name"]).head()
# Out:
#                Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# Variable_code
# H01            2023                     Level 1                99999
# H04            2023                     Level 1                99999
# H05            2023                     Level 1                99999
# H07            2023                     Level 1                99999
# H08            2023                     Level 1                99999
# ...             ...                         ...                  ...
# H38            2013                     Level 4                CC211
# H14            2013                     Level 1                   KK
# H14            2013                     Level 3                 KK11
# H14            2013                     Level 4                KK111
# H14            2013                     Level 4                KK112
#
#                             Industry_name_NZSIOC               Units  \
# Variable_code
# ...

# %%
survey.Year.sort
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_102991/2602994329.py in ?()
# ----> 1 survey.Year.sort()
#
# ~/myenv2/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'sort'
