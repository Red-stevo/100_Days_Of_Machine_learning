# %%
import pandas as pd
from matplotlib import pyplot as plt


data = pd.read_csv("./files/Electric_Production.xls")
data.head()
# Out:
#        DATE  IPG2211A2N
# 0  1/1/1985     72.5052
# 1  2/1/1985     70.6720
# 2  3/1/1985     62.4502
# 3  4/1/1985     57.4714
# 4  5/1/1985     55.3151

# %%
data.DATE.describe
# Out:
# <bound method NDFrame.describe of 0       1/1/1985
# 1       2/1/1985
# 2       3/1/1985
# 3       4/1/1985
# 4       5/1/1985
#          ...
# 392     9/1/2017
# 393    10/1/2017
# 394    11/1/2017
# 395    12/1/2017
# 396     1/1/2018
# Name: DATE, Length: 397, dtype: object>

# %%
data.DATE = pd.to_datetime(data.DATE)

# %%
data.DATE.describe
# Out:
# <bound method NDFrame.describe of 0     1985-01-01
# 1     1985-02-01
# 2     1985-03-01
# 3     1985-04-01
# 4     1985-05-01
#          ...
# 392   2017-09-01
# 393   2017-10-01
# 394   2017-11-01
# 395   2017-12-01
# 396   2018-01-01
# Name: DATE, Length: 397, dtype: datetime64[ns]>

# %%
data.sort_values(inplace=True, by="DATE")
data.head()
# Out:
#         DATE  IPG2211A2N
# 0 1985-01-01     72.5052
# 1 1985-02-01     70.6720
# 2 1985-03-01     62.4502
# 3 1985-04-01     57.4714
# 4 1985-05-01     55.3151

# %%
data.IPG2211A2N.describe
data = data.dropna()
data2 = data.query('DATE > "1985-01-01" and DATE < "1988-01-01"')

# %%
#plt.title("Electric Production Plot")
plt.xlabel("DATES")
plt.ylabel("IPG2211A2N")
plt.gcf().autofmt_xdate()
plt.xkcd()

plt.plot(data2.DATE, data2.IPG2211A2N, marker="o")
plt.show()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'Comic Sans MS' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'Comic Sans MS' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'Comic Sans MS' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'Comic Sans MS' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'Comic Sans MS' not found.
# findfont: Font family 'xkcd' not found.
# ...

# %%
plt.bar(data2.DATE, data2.IPG2211A2N)
plt.show()

# %%
data = pd.read_csv("./files/Electric_Production.xls")
data.head()
# Out:
#        DATE  IPG2211A2N
# 0  1/1/1985     72.5052
# 1  2/1/1985     70.6720
# 2  3/1/1985     62.4502
# 3  4/1/1985     57.4714
# 4  5/1/1985     55.3151

# %%
data.DATE = pd.to_datetime(data.DATE)

# %%
data1 = data.query('DATE > "1985-01-01" and DATE  < "1988-12-31"')
data2 = data.query('DATE > "1989-01-01" and DATE  < "1993-12-31"')
data3 = data.query('DATE > "1994-01-01" and DATE  < "1998-12-31"')

# %%
# plt.title("Electric Production")
plt.xlabel("DATES")
plt.ylabel("IPG2211A2N")
plt.style.use("ggplot")
plt.gcf().autofmt_xdate()
plt.legend(["1985 - 1988", "1989 - 1993", "1994 - 1998"])

plt.fill_between(data1.DATE,data1.IPG2211A2N)
plt.fill_between(data2.DATE,data2.IPG2211A2N)
plt.fill_between(data3.DATE,data3.IPG2211A2N)

plt.plot(data1.DATE, data1.IPG2211A2N, color="#440000", label="1985 - 1988")
plt.plot(data2.DATE, data2.IPG2211A2N, color="#005500", label="1989 - 1993")
plt.plot(data3.DATE, data3.IPG2211A2N, color="#000066", label="1994 - 1998")
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'Comic Sans MS' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'Comic Sans MS' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'Comic Sans MS' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'Comic Sans MS' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'Comic Sans MS' not found.
# findfont: Font family 'xkcd' not found.
# ...
